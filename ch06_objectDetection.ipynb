# %% [markdown]
# ### 객체인식을 위한 신경망

# %% [markdown]
# ![image.png](attachment:8fce529b-d360-4912-a98f-c0a434604864.png)

# %% [markdown]
# ![image.png](attachment:aec3a047-c882-4363-ba22-ab4a50970a9c.png)

# %% [markdown]
# ![image.png](attachment:ef6848ce-b9fd-4127-b410-a249b778266f.png)

# %% [markdown]
# ### 이미지라벨링
# https://www.cvat.ai/
